# %%
#To add a support condition to a cell, change the metadata of a cell like in the examples below

# %%
#Generic
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Generic
# ----> 2 error
#
# NameError: name 'error' is not defined

# %%
#Personalized
error
print(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Personalized
# ----> 2 error
#       3 print(5)
#
# NameError: name 'error' is not defined

# %%
#CustomPrompt
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #CustomPrompt
# ----> 2 error
#
# NameError: name 'error' is not defined

# %%
#NoSupport (still gets logged)
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #NoSupport (still gets logged)
# ----> 2 error
#
# NameError: name 'error' is not defined
